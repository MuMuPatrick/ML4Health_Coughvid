# %%
import time
import os, sys

from coughvid_dataset import CoughvidDataset

PATH_TO_DATASET = "D:\COUGHVID_public_dataset\public_dataset"
mask_dir = "D:\COUGHVID_public_dataset\segmentation.npy"

# %%
covid_set = CoughvidDataset(PATH_TO_DATASET, mask_dir)
covid_set[1420] #I randomly try with one of the instance in the database
# Out:
# 10817 records ready to load.
# D:\COUGHVID_public_dataset\public_dataset\225cf920-b008-43d4-92e3-6640aaddd431.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:124: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# ([[tensor([[-4.1217e+02, -4.0226e+02, -4.1075e+02, -3.9453e+02],
#            [ 4.7076e+01,  3.5441e+01,  3.9291e+01,  5.1157e+01],
#            [-1.6776e+01, -2.5385e+01, -2.3557e+01, -2.6254e+01],
#            [ 3.9162e+00,  1.1120e+00,  9.5223e+00, -2.9234e+00],
#            [-1.0744e+00, -4.7608e+00,  5.7150e+00,  7.1874e+00],
#            [ 5.0943e+00,  3.2933e+00,  6.1612e+00,  1.1941e+01],
#            [-8.1202e+00, -1.0382e+01, -5.6084e+00, -6.1882e+00],
#            [ 3.4865e+00,  3.0323e+00,  6.0395e+00,  1.5426e+01],
#            [-5.8659e+00, -1.5996e+01, -7.0357e+00, -6.5699e+00],
#            [ 9.4660e+00,  2.9718e+00,  2.7194e+00, -6.9736e+00],
# ...
